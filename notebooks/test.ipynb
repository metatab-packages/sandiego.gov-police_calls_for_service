# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
#pkg = mp.jupyter.open_package()
pkg = doc = mp.jupyter.open_source_package()
pkg
# Out:
# # San Diego Police Calls for Service
# `sandiego.gov-police_calls_for_service-1.1.1` Last Update: 2020-06-11T21:41:10
#
# _San Diego Police Calls for Service, linked to related datasets_
#
#
# This dataset links to the San Dieg Police Calls for Service datasets, from multiple years, combine the years and lints to the destriptions of disposition codes and beat neighborhoods.
#
#
# # Caveats and Adjustments
#
# The meaning of the numbers in the `day_of_week` column has changed from earlier
# to later years. Earlier years use values from 0 to 6, while later years use
# vlaues from 1 to 7. Because of this, the `day_of_week` vlaues have been re-calculated to the span from 0 to 6, where 0 is Monday and 6 is Sunday.
# ## Documentation Links
#
# * [Priority codes](http://seshat.datasd.org/pd/pd_cfs_priority_defs_datasd.pdf)
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [sdpd_calls_for_service](notebooks/Combine.ipynb#df)**. San Diego Police Calls for Service, 2015 to 2020
#
# ## References
# <ul><li> <strong><a href="http://seshat.datasd.org/pd/pd_calls_for_service_2015_datasd_v1.csv">calls_for_service_source_2015</a></strong>. San Diego Police Calls for Service, 2015</li><li> <strong><a href="http://seshat.datasd.org/pd/pd_calls_for_service_2016_datasd_v1.csv">calls_for_service_source_2016</a></strong>. San Diego Police Calls for Service, 2016</li><li> <strong><a href="http://seshat.datasd.org/pd/pd_calls_for_service_2017_datasd_v1.csv">calls_for_service_source_2017</a></strong>. San Diego Police Calls for Service, 2017</li><li> <strong><a href="http://seshat.datasd.org/pd/pd_calls_for_service_2018_datasd.csv">calls_for_service_source_2018</a></strong>. San Diego Police Calls for Service, 2018</li><li> <strong><a href="http://seshat.datasd.org/pd/pd_calls_for_service_2019_datasd.csv">calls_for_service_source_2019</a></strong>. San Diego Police Calls for Service, 2019</li><li> <strong><a href="http://seshat.datasd.org/pd/pd_calls_for_service_2020_datasd.csv">calls_for_service_source_2020</a></strong>. San Diego Police Calls for Service, 2020</li><li> <strong><a href="http://seshat.datasd.org/pd/pd_dispo_codes_historical_datasd.csv">disp_codes_2017</a></strong>. Disposition Codes, prior to October 17, 2017</li><li> <strong><a href="http://seshat.datasd.org/pd/pd_dispo_codes_datasd.csv">disp_codes</a></strong>. Current disposition codes</li><li> <strong><a href="http://seshat.datasd.org/pd/pd_beat_neighborhoods_datasd.csv">beat_codes</a></strong>. Beat Neighborhood Codes</li><ul>

# %%
frames = []

for r in pkg.references():
    
    if r.name.startswith('calls_for_service'):
        frames.append(r.dataframe())

cfs = pd.concat(frames)

# %%
cfs.head().T
# Out:
#                                              0                    1  \
# incident_num                      P15010000001         P15010000002
# date_time                  2015-01-01 00:00:14  2015-01-01 00:00:30
# day_of_week                                  3                    3
# address_number_primary                    3800                    0
# address_dir_primary                        NaN                  NaN
# address_road_primary                     DELTA                 60TH
# address_sfx_primary                         ST                   ST
# address_dir_intersecting                   NaN                  NaN
# address_road_intersecting                  NaN              FEDERAL
# address_sfx_intersecting                   NaN                   BL
# call_type                                  AU1                  AU1
# disposition                                  K                  DUP
# beat                                       443                  433
# priority                                     1                    1
#
#                                              2                    3  \
# incident_num                      P15010000003         P15010000004
# date_time                  2015-01-01 00:00:48  2015-01-01 00:00:57
# day_of_week                                  3                    3
# address_number_primary                    3600                    0
# address_dir_primary                        NaN                  NaN
# address_road_primary                     LOGAN                 33RD
# address_sfx_primary                         AV                   ST
# address_dir_intersecting                   NaN                  NaN
# address_road_intersecting                  NaN             IMPERIAL
# address_sfx_intersecting                   NaN                   AV
# call_type                                  AU1                  AU1
# disposition                                DUP                    K
# beat                                       441                  512
# priority                                     1                    1
#
#                                              4
# incident_num                      P15010000005
# date_time                  2015-01-01 00:01:05
# day_of_week                                  3
# address_number_primary                    3300
# address_dir_primary                        NaN
# address_road_primary                      43RD
# address_sfx_primary                         ST
# address_dir_intersecting                   NaN
# address_road_intersecting                  NaN
# address_sfx_intersecting                   NaN
# call_type                                  AU1
# disposition                                  O
# beat                                       834
# priority                                     1

# %%
# Combine the disposition codes. It looks like there are some name changes, but mostly the laster 
# file is a superset of the earlier one
disp = pd.concat([pkg.reference('disp_codes').dataframe(), pkg.reference('disp_codes_2017').dataframe()]).sort_values('dispo_code')
disp.drop_duplicates(subset=['dispo_code'])
# Out:
#    dispo_code                                        description
# 0           A                                             ARREST
# 33        AAC                       ARREST (MID CITY ADMIN CITE)
# 2          AB                      ARREST MADE, BOARD AND SECURE
# 25         AC                  ARREST, CHRONIC DOMESTIC VIOLENCE
# 11         AG                                    ARREST, TOY GUN
# 3         AHR      ARREST MADE, HIGH RISK (CRISIS RESPONSE TEAM)
# 16         AM                     ARREST, MENTAL ILLNESS RELATED
# 20         AT                          ARREST, TRANSIENT RELATED
# 9         CAN                                             CANCEL
# 16        DUP                             DUPLICATE CALL, XREF'D
# 10          K                                 NO REPORT REQUIRED
# 35        KAC      NO FURTHER ACTION TAKEN (MID CITY ADMIN CITE)
# 40         KB                 NO REPORT REQUIRED, BOARD & SECURE
# 27         KC  NO FURTHER ACTION TAKEN, CHRONIC DOMESTIC VIOL...
# 14         KG                         NO FURTHER ACTION, TOY GUN
# 32        KHR  NO FURTHER ACTION, HIGH RISK, (CRISIS RESPONSE...
# 18         KM    NO FURTHER ACTION TAKEN, MENTAL ILLNESS RELATED
# 22         KT         NO FURTHER ACTION TAKEN, TRANSIENT RELATED
# 7           O                                              OTHER
# 37        OAC                        OTHER (MID CITY ADMIN CITE)
# 15         OG                                     OTHER, TOY GUN
# 9         OHR            OTHER, HIGH RISK (CRISIS RESPONSE TEAM)
# 19         OM                      OTHER, MENTAL ILLNESS RELATED
# 24         OT                                  TRANSIENT RELATED
# 4           R                                             REPORT
# 34        RAC                       REPORT (MID CITY ADMIN CITE)
# 5          RB                     REPORT TAKEN, BOARD AND SECURE
# 26         RC            REPORT TAKEN, CHRONIC DOMESTIC VIOLENCE
# 12         RG                                    REPORT, TOY GUN
# 6         RHR           REPORT, HIGH RISK (CRISIS RESPONSE TEAM)
# 17         RM               REPORT TAKEN, MENTAL ILLNESS RELATED
# 21         RT                    REPORT TAKEN, TRANSIENT RELATED
# 7           S                STOLEN VEHICLE OR RECOVERED VEHICLE
# 13          U                                          UNFOUNDED
# 28         UC               UNFOUNDED, CHRONIC DOMESTIC VIOLENCE
# 13         UG                                 UNFOUNDED, TOY GUN
# 23         UT                       UNFOUNDED, TRANSIENT RELATED
# 17          V                                     DUPLICATE CALL
# 36        VAC                    DUPE CALL (MID CITY ADMIN CITE)
# 3           W  NO DISPATCH OR INCIDENT CANCELLED PRIOR TO DIS...
# 8           X  DISPATCHED ALARM CALL CANCELLED BEFORE UNIT ON...

# %%
beats = pkg.reference('beat_codes').dataframe()

# %%
df = cfs.merge(beats.rename(columns={'Beat':'beat'})).merge(disp.rename(columns={'dispo_code':'disposition'}))
df['date_time'] = pd.to_datetime(df.date_time)
df['day_of_week'] = df.date_time.dt.dayofweek
